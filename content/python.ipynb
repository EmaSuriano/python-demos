# %% [markdown]
# ## A Python kernel running in the browser
#
# Feel free to modify this file the way you wanted, it's running in your browser enjoy it!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)  # For reproducibility

# Generate a DataFrame with synthetic data
data = {
    'A': np.random.normal(0, 1, 1000),
    'B': np.random.normal(5, 2, 1000),
    'C': np.random.normal(-2, 4, 1000),
    'Category': np.random.choice(['X', 'Y', 'Z'], 1000)
}

df = pd.DataFrame(data)
df.head()
# Out:
#           A         B         C Category
# 0  0.496714  7.798711 -4.700713        Y
# 1 -0.138264  6.849267 -2.578075        Y
# 2  0.647689  5.119261 -5.169680        Y
# 3  1.523030  3.706126 -3.231846        X
# 4 -0.234153  6.396447 -9.574459        Z

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 3, 1)
plt.hist(df['A'], bins=30, color='blue', alpha=0.7)
plt.title('Distribution of A')
plt.xlabel('A')
plt.ylabel('Frequency')

plt.subplot(1, 3, 2)
plt.hist(df['B'], bins=30, color='green', alpha=0.7)
plt.title('Distribution of B')
plt.xlabel('B')
plt.ylabel('Frequency')

plt.subplot(1, 3, 3)
plt.hist(df['C'], bins=30, color='red', alpha=0.7)
plt.title('Distribution of C')
plt.xlabel('C')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
mean_by_category = df.groupby('Category').mean().reset_index()

mean_by_category.set_index('Category', inplace=True)
mean_by_category.plot(kind='bar', figsize=(10, 6))

plt.title('Mean Values by Category')
plt.xlabel('Category')
plt.ylabel('Mean Value')
plt.xticks(rotation=0)
plt.show()
